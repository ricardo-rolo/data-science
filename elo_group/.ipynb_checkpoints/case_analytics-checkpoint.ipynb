# %% [markdown]
# # Case Analytics - Ricardo Rolo de Almeida
#
# ---
#
# ## 1. Conhecendo a base de dados

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./df_criado_final.csv')
df.head()
# Out:
#    Escolaridade  Renda Mensal Informal Dependentes  Estado Civil  Idade  \
# 0           NaN                    NaN           S             2     36
# 1           1.0              1894.5078           N             2     39
# 2           1.0                    NaN           S             2     26
# 3           NaN                    NaN           N             8     23
# 4           NaN                    NaN           S             2     33
#
#   Conta Poupanca Conta Salario  Quant Adiantamento Deposito  Qtd Fonte Renda  \
# 0              S             N                          NaN              NaN
# 1              S             N                          2.0              1.0
# 2              S             N                          NaN              1.0
# 3              N             N                          NaN              NaN
# 4              S             N                          NaN              NaN
#
#   Cheque Sem Fundo  ... Valor Emprestimo     Multa      Juros  \
# 0                N  ...          8174.32    263.25    5844.98
# 1                S  ...         41775.63   1607.29    7652.26
# 2                S  ...        522940.27  24860.40  319315.62
# 3                N  ...          1593.00  21472.36    2967.48
# 4                N  ...          2078.97     19.44      46.35
#
#    Valor Emprestimo Atualizado  PAGO  Controle         ID  Genero        Data  \
# 0                     14282.55     1         1  1328587.0       1  2020-01-01
# 1                     51035.18     1         1  1424254.0       1  2020-01-01
# 2                    867116.29     1         1  1438519.0       0  2020-01-01
# 3                     26032.84     1         1  1426138.0       1  2020-01-01
# 4                      2144.76     1         1  1474504.0       0  2020-01-01
#
#    Estado
# 0      57
# 1      59
# 2      56
# 3      56
# 4      59
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 1.1 Tipos de Dados

# %%
df.shape
# Out:
# (50390, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50390 entries, 0 to 50389
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Escolaridade                 14615 non-null  float64
#  1   Renda Mensal Informal        9768 non-null   float64
#  2   Dependentes                  50390 non-null  object
#  3   Estado Civil                 50390 non-null  int64
#  4   Idade                        50390 non-null  int64
#  5   Conta Poupanca               50390 non-null  object
#  6   Conta Salario                50390 non-null  object
#  7   Quant Adiantamento Deposito  21843 non-null  float64
#  8   Qtd Fonte Renda              12806 non-null  float64
#  9   Cheque Sem Fundo             50390 non-null  object
#  10  Conta Conjunta               50390 non-null  object
#  11  Valor Conta Corrente         0 non-null      float64
#  12  Valor Conta Poupanca         0 non-null      float64
#  13  Valor Emprestimo             50390 non-null  float64
#  14  Multa                        50390 non-null  float64
#  15  Juros                        50390 non-null  float64
#  16  Valor Emprestimo Atualizado  50390 non-null  float64
#  17  PAGO                         50390 non-null  int64
#  18  Controle                     50390 non-null  int64
#  19  ID                           50390 non-null  float64
#  20  Genero                       50390 non-null  int64
#  21  Data                         50390 non-null  object
#  22  Estado                       50390 non-null  int64
# dtypes: float64(11), int64(6), object(6)
# memory usage: 8.8+ MB

# %% [markdown]
# > Como pudemos ver, nosso dataset possui: 50390 **linhas** e 23 **colunas** de dados, sendo eles, majoritariamente, valores **numéricos**, contendo também valores **booleanos** (Conta Poupanca, Conta Salario, Cheque Sem Fundo, etc) e **numéricos categóricos** (Escolaridade, Estado Civil, Gênero e Estado).
#
# > **Comentário:** o campo 'ID' (Identificação do tomador de crédito) é do tipo float, isso pode ser rapidamente corrigido, porém, normalmente, campos de identificação são armazenados como números inteiros (vamos mudá-lo abaixo).
# Vamos mudar também o tipo da variável 'Escolaridade' para o tipo int64

# %%
df['ID'] = df['ID'].astype('int64')

# %%
df.head()
# Out:
#    Escolaridade  Renda Mensal Informal Dependentes  Estado Civil  Idade  \
# 0           NaN                    NaN           S             2     36
# 1           1.0              1894.5078           N             2     39
# 2           1.0                    NaN           S             2     26
# 3           NaN                    NaN           N             8     23
# 4           NaN                    NaN           S             2     33
#
#   Conta Poupanca Conta Salario  Quant Adiantamento Deposito  Qtd Fonte Renda  \
# 0              S             N                          NaN              NaN
# 1              S             N                          2.0              1.0
# 2              S             N                          NaN              1.0
# 3              N             N                          NaN              NaN
# 4              S             N                          NaN              NaN
#
#   Cheque Sem Fundo  ... Valor Emprestimo     Multa      Juros  \
# 0                N  ...          8174.32    263.25    5844.98
# 1                S  ...         41775.63   1607.29    7652.26
# 2                S  ...        522940.27  24860.40  319315.62
# 3                N  ...          1593.00  21472.36    2967.48
# 4                N  ...          2078.97     19.44      46.35
#
#    Valor Emprestimo Atualizado  PAGO  Controle       ID  Genero        Data  \
# 0                     14282.55     1         1  1328587       1  2020-01-01
# 1                     51035.18     1         1  1424254       1  2020-01-01
# 2                    867116.29     1         1  1438519       0  2020-01-01
# 3                     26032.84     1         1  1426138       1  2020-01-01
# 4                      2144.76     1         1  1474504       0  2020-01-01
#
#    Estado
# 0      57
# 1      59
# 2      56
# 3      56
# 4      59
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 1.2 Características dos Dados
#
# Para análise de aprovação de crédito, usa-se, comumente, os seguintes dados (candidatas a possíveis variáveis preditoras):
#
# - CPF
# - Nível de Escolaridade
# - Profissão
# - Renda
# - Idade
# - Bens de garantia
# - Histórico de pagamento
#
# Abaixo, vamos analisar quais desses dados nós possuímos no nosso dataset

# %%
df.columns
# Out:
# Index(['Escolaridade', 'Renda Mensal Informal', 'Dependentes', 'Estado Civil',
#        'Idade', 'Conta Poupanca', 'Conta Salario',
#        'Quant Adiantamento Deposito', 'Qtd Fonte Renda', 'Cheque Sem Fundo',
#        'Conta Conjunta', 'Valor Conta Corrente', 'Valor Conta Poupanca',
#        'Valor Emprestimo', 'Multa', 'Juros', 'Valor Emprestimo Atualizado',
#        'PAGO', 'Controle', 'ID', 'Genero', 'Data', 'Estado'],
#       dtype='object')

# %% [markdown]
# > Vimos que, dos dados comumente usados, temos, a princípio:
#
# |           Dado           |                                                       Coluna(s)                                                       |
# |:------------------------:|:---------------------------------------------------------------------------------------------------------------------:|
# |   Nível de Escolaridade  |                                                      Escolaridade                                                     |
# |   Histórico de Pagamento |                PAGO, Cheque Sem Fundo, Valor Emprestimo, Multa, Juros, Valor Emprestimo Atualizado                    |
# |            Renda         | Renda Mensal Informal, Conta Poupanca, Conta Salario, Conta Conjunta, Valor Conta Corrente, Valor Conta Poupanca      |
# |           Idade          |                                                         Idade                                                         |
#
# ##### Agora, vamos verificar quais desses dados estão bem definidos no nosso dataset para que possamos definir quais podem e quais não podem ser usados

# %% [markdown]
# ## 2. Tratamento da base de dados (Valores Faltantes, Duplicatas)
#
# ### 2.1 Valores Faltantes

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis') #fonte: https://github.com/krishnaik06/EDA1/blob/master/EDA.ipynb

# %%
df.columns[df.isnull().all()]
# Out:
# Index(['Valor Conta Corrente', 'Valor Conta Poupanca'], dtype='object')

# %% [markdown]
# > De cara, percebe-se que há duas colunas que possuem **APENAS** valores nulos (Valor Conta Corrente, Valor Conta Poupanca).
# > Aqui cabe uma **crítica**: como não possuímos nenhum **valor** de renda **formal** declarada, isso pode dificultar na previsão do nosso modelo, visto que, dessa forma, teríamos apenas a coluna de Renda Mensal Informal que pode conter valores ou não (Ex: se o cliente não possuir renda informal ou não declará-la) além desse valor poder variar mensalmente.
# Como estas duas colunas **NÃO** possuem valor algum, podemos dizer, com mais segurança, que elas podem ser removidas.

# %%
# remoção das duas colunas nulas
df.drop(columns=['Valor Conta Corrente', 'Valor Conta Poupanca'], inplace=True)

# %%
df.head()
# Out:
#    Escolaridade  Renda Mensal Informal Dependentes  Estado Civil  Idade  \
# 0           NaN                    NaN           S             2     36
# 1           1.0              1894.5078           N             2     39
# 2           1.0                    NaN           S             2     26
# 3           NaN                    NaN           N             8     23
# 4           NaN                    NaN           S             2     33
#
#   Conta Poupanca Conta Salario  Quant Adiantamento Deposito  Qtd Fonte Renda  \
# 0              S             N                          NaN              NaN
# 1              S             N                          2.0              1.0
# 2              S             N                          NaN              1.0
# 3              N             N                          NaN              NaN
# 4              S             N                          NaN              NaN
#
#   Cheque Sem Fundo  ... Valor Emprestimo     Multa      Juros  \
# 0                N  ...          8174.32    263.25    5844.98
# 1                S  ...         41775.63   1607.29    7652.26
# 2                S  ...        522940.27  24860.40  319315.62
# 3                N  ...          1593.00  21472.36    2967.48
# 4                N  ...          2078.97     19.44      46.35
#
#    Valor Emprestimo Atualizado  PAGO  Controle       ID  Genero        Data  \
# 0                     14282.55     1         1  1328587       1  2020-01-01
# 1                     51035.18     1         1  1424254       1  2020-01-01
# 2                    867116.29     1         1  1438519       0  2020-01-01
# 3                     26032.84     1         1  1426138       1  2020-01-01
# 4                      2144.76     1         1  1474504       0  2020-01-01
#
#   Estado
# 0     57
# 1     59
# 2     56
# 3     56
# 4     59
#
# [5 rows x 21 columns]

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['Escolaridade', 'Renda Mensal Informal', 'Quant Adiantamento Deposito',
#        'Qtd Fonte Renda'],
#       dtype='object')

# %% [markdown]
# > Acima vemos quais colunas do dataframe possem 1 ou mais valores nulos, abaixo faremos uma análise dessas colunas:

# %%
missing_values = pd.DataFrame()

missing_values['Nulos'] = df.isnull().sum() # Aqui checamos quantos valores nulos existem em cada coluna do nosso DataFrame

missing_values = missing_values[missing_values['Nulos'] > 0] # Filtramos o dataframe para mostrar apenas as colunas que possuem valores nulos

# %%
sns.barplot(x=missing_values.index, y=missing_values.Nulos, data=missing_values, order=missing_values.index)
plt.xticks(rotation = 80)
plt.ylabel("% de Valores Nulos")
plt.title("Análise de Valores Nulos nas Colunas do DataFrame")
# Out:
# Text(0.5, 1.0, 'Análise de Valores Nulos nas Colunas do DataFrame')

# %% [markdown]
# ##### Acima vemos que as seguintes colunas do dataset ainda posssuem valores faltantes:
#
# - Escolaridade
# - Renda Mensal Informal
# - Quant Adiantamento Deposito
# - Qtd Fonte Renda

# %% [markdown]
# > ##### **Comentário:** A coluna 'Renda Mensal Informal', mesmo possuindo valores nulos, poderia talvez ser utilizada no modelo, já que nem todos os clientes possuem Renda Informal declarada, o que pode explicar seus valores faltantes no dataset. Vamos tratá-la abaixo preenchendo os valores nulos com 0.

# %%
df['Renda Mensal Informal'] = df['Renda Mensal Informal'].fillna(value=0)

# %%
df.head()
# Out:
#    Escolaridade  Renda Mensal Informal Dependentes  Estado Civil  Idade  \
# 0           NaN                 0.0000           S             2     36
# 1           1.0              1894.5078           N             2     39
# 2           1.0                 0.0000           S             2     26
# 3           NaN                 0.0000           N             8     23
# 4           NaN                 0.0000           S             2     33
#
#   Conta Poupanca Conta Salario  Quant Adiantamento Deposito  Qtd Fonte Renda  \
# 0              S             N                          NaN              NaN
# 1              S             N                          2.0              1.0
# 2              S             N                          NaN              1.0
# 3              N             N                          NaN              NaN
# 4              S             N                          NaN              NaN
#
#   Cheque Sem Fundo  ... Valor Emprestimo     Multa      Juros  \
# 0                N  ...          8174.32    263.25    5844.98
# 1                S  ...         41775.63   1607.29    7652.26
# 2                S  ...        522940.27  24860.40  319315.62
# 3                N  ...          1593.00  21472.36    2967.48
# 4                N  ...          2078.97     19.44      46.35
#
#    Valor Emprestimo Atualizado  PAGO  Controle       ID  Genero        Data  \
# 0                     14282.55     1         1  1328587       1  2020-01-01
# 1                     51035.18     1         1  1424254       1  2020-01-01
# 2                    867116.29     1         1  1438519       0  2020-01-01
# 3                     26032.84     1         1  1426138       1  2020-01-01
# 4                      2144.76     1         1  1474504       0  2020-01-01
#
#   Estado
# 0     57
# 1     59
# 2     56
# 3     56
# 4     59
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### Como 2 dessas colunas (Escolaridade e Qtd Fonte Renda) **NÃO** possuem mais de 60% dos seus valores, e preenchê-las não nos ajudaria, vamos removê-las para evitar que isto cause confusão no nosso modelo futuramente.

# %%
# remoção das 3 colunas no dataset
df.drop(labels=['Escolaridade', 'Qtd Fonte Renda'], axis='columns', inplace=True)

# %%
df.head()
# Out:
#    Renda Mensal Informal Dependentes  Estado Civil  Idade Conta Poupanca  \
# 0                 0.0000           S             2     36              S
# 1              1894.5078           N             2     39              S
# 2                 0.0000           S             2     26              S
# 3                 0.0000           N             8     23              N
# 4                 0.0000           S             2     33              S
#
#   Conta Salario  Quant Adiantamento Deposito Cheque Sem Fundo Conta Conjunta  \
# 0             N                          NaN                N              N
# 1             N                          2.0                S              N
# 2             N                          NaN                S              N
# 3             N                          NaN                N              N
# 4             N                          NaN                N              N
#
#    Valor Emprestimo     Multa      Juros  Valor Emprestimo Atualizado  PAGO  \
# 0           8174.32    263.25    5844.98                     14282.55     1
# 1          41775.63   1607.29    7652.26                     51035.18     1
# 2         522940.27  24860.40  319315.62                    867116.29     1
# 3           1593.00  21472.36    2967.48                     26032.84     1
# 4           2078.97     19.44      46.35                      2144.76     1
#
#    Controle       ID  Genero        Data  Estado
# 0         1  1328587       1  2020-01-01      57
# 1         1  1424254       1  2020-01-01      59
# 2         1  1438519       0  2020-01-01      56
# 3         1  1426138       1  2020-01-01      56
# 4         1  1474504       0  2020-01-01      59

# %% [markdown]
# ##### Em relação às Datas presentes no dataset, vemos abaixo que **TODOS** os nossos dados tiveram sua última atualização no início do ano de 2020

# %%
df.Data.unique()
# Out:
# array(['2020-01-01'], dtype=object)

# %% [markdown]
# ### 2.2 Duplicatas

# %% [markdown]
# #### Coluna 'ID'

# %%
duplicated_values = df[df.duplicated(subset=['ID'], keep=False)]
duplicated_values.sort_values(by='ID')
# Out:
#        Renda Mensal Informal Dependentes  Estado Civil  Idade Conta Poupanca  \
# 11568                 0.0000           S             2     32              S
# 32141                71.4624           N             2     31              S
# 37485                 0.0000           S             2     38              S
# 43156                 0.0000           N             4     33              S
# 21023                 2.6900           N             2     37              S
# ...                      ...         ...           ...    ...            ...
# 38943              1250.1980           N             2     30              S
# 42230                 0.0000           N             8     31              N
# 42229                 0.0000           N             8     31              N
# 42234                 0.0000           N             8     31              N
# 42235                 0.0000           N             8     31              N
#
#       Conta Salario  Quant Adiantamento Deposito Cheque Sem Fundo  \
# 11568             N                          NaN                N
# 32141             N                          NaN                N
# 37485             N                          2.0                S
# 43156             N                          2.0                N
# 21023             N                          2.0                N
# ...             ...                          ...              ...
# 38943             N                          2.0                N
# 42230             N                          2.0                N
# 42229             N                          2.0                N
# 42234             N                          2.0                N
# 42235             N                          2.0                N
#
#       Conta Conjunta  Valor Emprestimo     Multa      Juros  \
# 11568              N           1923.36     13.21     354.01
# 32141              N           9730.35    975.29    9312.20
# 37485              N           1593.00   3015.06    2882.26
# 43156              N           7053.00    218.40    5469.45
# 21023              N          64605.42   2520.51   63826.29
# ...              ...               ...       ...        ...
# 38943              N           1593.00  66834.90   41898.80
# 42230              N          54131.41  52538.41  100295.82
# 42229              N          12618.21  11025.21   21047.13
# 42234              N          29925.33  28332.33   53712.43
# 42235              N          33826.13  32233.13   61107.57
#
#        Valor Emprestimo Atualizado  PAGO  Controle           ID  Genero  \
# 11568                      2290.58     1         1      1284016       0
# 32141                     20017.84     1         1      1284016       1
# 37485                      7490.32     1         1      1304080       0
# 43156                     12740.85     0         1      1304080       1
# 21023                     30790.22     1         1      1304200       1
# ...                            ...   ...       ...          ...     ...
# 38943                     10164.70     1         1  21631527280       0
# 42230                    106803.64     0         1  23997864880       1
# 42229                     44690.55     0         1  23997864880       1
# 42234                     11808.09     0         1  23997864892       0
# 42235                     27004.83     0         1  23997864892       0
#
#              Data  Estado
# 11568  2020-01-01      58
# 32141  2020-01-01      59
# 37485  2020-01-01      59
# 43156  2020-01-01      58
# 21023  2020-01-01      59
# ...           ...     ...
# 38943  2020-01-01      58
# 42230  2020-01-01      58
# 42229  2020-01-01      58
# 42234  2020-01-01      59
# 42235  2020-01-01      56
#
# [9212 rows x 19 columns]

# %% [markdown]
# > ##### Comentário: Mesmo tendo valores repetidos na coluna 'ID', temos diversas combinações diferentes quando analisamos estas junto com a coluna 'Estado' (e as demais colunas como: 'Idade', 'Dependentes', 'Qtd Fonte Renda', 'Renda Mensal Informal', etc). Logo, entende-se que 'ID' e 'Estado' possuem uma relação de dependência mútua, trabalhando como chave primária da nossa tabela.

# %% [markdown]
# ### 3. Análise das Variáveis
#
# #### 3.1 Variáveis Numéricas

# %%
df.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#        Estado Civil         Idade Quant Adiantamento Deposito  \
# count  50390.000000  50390.000000                50390.000000
# mean       3.503354     31.724529                    0.912443
# std        2.132091      8.565117                    1.199169
# min        1.000000     18.000000                    0.000000
# 25%        2.000000     26.000000                    0.000000
# 50%        2.000000     30.000000                    0.000000
# 75%        4.000000     35.000000                    2.000000
# max       11.000000    113.000000                   18.000000
#
#        Valor Emprestimo             Multa             Juros  \
# count      50390.000000      50390.000000      50390.000000
# mean       51989.266062      60226.580975      64853.905193
# std      1588818.991816    2843941.338603    2728170.116998
# min         1431.000000          0.000000          0.000000
# 25%         1593.000000        132.567500        274.272500
# 50%         2298.035000        648.965000       1143.320000
# 75%         7172.175000       3600.000000       5545.427500
# max    286789375.440000  573775888.890000  570361922.350000
#
#       Valor Emprestimo Atualizado          PAGO      Controle  \
# count                50390.000000  50390.000000  50390.000000
# mean                172177.934766      0.790891      1.000000
# std                7058289.875381      0.406676      0.000000
# min                   1441.500000      0.000000      1.000000
# 25%                   2840.910000      1.000000      1.000000
# 50%                   5609.805000      1.000000      1.000000
# 75%                  17913.245000      1.000000      1.000000
# max             1430927186.680000      1.000000      1.000000
#
#                        ID        Genero        Estado
# count        50390.000000  50390.000000  50390.000000
# mean    3740828945.697599      0.498333     57.498055
# std     7248461992.172623      0.500002      1.118008
# min        1168846.000000      0.000000     56.000000
# 25%        1383124.000000      0.000000     56.000000
# 50%        1439557.000000      0.000000     57.000000
# 75%       46996419.250000      1.000000     58.000000
# max    23998870468.000000      1.000000     59.000000

# %% [markdown]
# ##### Comentário: na tabela acima vemos que algumas das colunas numéricas possuem outliers (pontos fora da curva). Vamos tratá-los abaixo

# %% [markdown]
# ##### 'Valor Emprestimo'

# %%
Q1_emprestimo = df['Valor Emprestimo'].quantile(0.25)
Q3_emprestimo = df['Valor Emprestimo'].quantile(0.75)
IQR_emprestimo = Q3_emprestimo - Q1_emprestimo

Lower_Whisker_emprestimo = Q1_emprestimo - (1.5 * IQR_emprestimo)
Upper_Whisker_emprestimo = Q3_emprestimo + (1.5 * IQR_emprestimo)
outliers_emprestimo = df[(df['Valor Emprestimo'] > Upper_Whisker_emprestimo) | (df['Valor Emprestimo'] < Lower_Whisker_emprestimo)]['Valor Emprestimo'].count()

print('Primeiro Quartil: ' + str(Q1_emprestimo))
print('Terceiro Quartil: ' + str(Q3_emprestimo))
print('Amplitude: ' + str(IQR_emprestimo))
print('Quantidade de Outliers: ' + str(outliers_emprestimo))
# Out:
# Primeiro Quartil: 1593.0
# Terceiro Quartil: 7172.174999999999
# Amplitude: 5579.174999999999
# Quantidade de Outliers: 7568

# %% [markdown]
# ##### Vamos eliminar esses valores:

# %%
index = df[(df['Valor Emprestimo'] > Upper_Whisker_emprestimo) | (df['Valor Emprestimo'] < Lower_Whisker_emprestimo)].index
df.drop(index, inplace=True)

# %%
df.shape
# Out:
# (42822, 18)

# %%
df.sort_values(by='Valor Emprestimo', ascending=False)
# Out:
#       Dependentes  Estado Civil  Idade Conta Poupanca Conta Salario  \
# 28063           S             2     31              S             N
# 34549           S             2     35              S             N
# 44824           S             2     30              S             N
# 22847           N             8     29              N             N
# 46889           S             2     27              S             N
# ...           ...           ...    ...            ...           ...
# 5342            N             4     33              S             N
# 43043           N             2     29              S             N
# 43131           S             2     33              S             N
# 15630           S             2     29              S             N
# 17138           N             2     51              S             N
#
#        Quant Adiantamento Deposito Cheque Sem Fundo Conta Conjunta  \
# 28063                          2.0                N              N
# 34549                          0.0                N              N
# 44824                          2.0                N              N
# 22847                          0.0                N              N
# 46889                          0.0                N              N
# ...                            ...              ...            ...
# 5342                           2.0                N              N
# 43043                          0.0                N              N
# 43131                          2.0                N              N
# 15630                          0.0                S              N
# 17138                          2.0                N              N
#
#        Valor Emprestimo      Multa      Juros  Valor Emprestimo Atualizado  \
# 28063          15537.42     557.78    2004.20                     18099.40
# 34549          15534.53     557.66    7438.08                     23530.27
# 44824          15527.55   28579.73   35568.06                     79675.34
# 22847          15525.94     557.32    7691.43                     23774.69
# 46889          15522.60   13929.60   17701.70                     47153.90
# ...                 ...        ...        ...                          ...
# 5342            1549.93    4004.76   99698.31                    105253.00
# 43043           1545.00  320364.60  358341.91                    680251.51
# 43131           1540.80  100109.80  155399.85                    257050.45
# 15630           1496.48    4002.63   49738.49                     55237.60
# 17138           1431.00   20000.00    6024.00                     27455.00
#
#        PAGO  Controle           ID  Genero        Data  Estado
# 28063     1         1      1455496       0  2020-01-01      57
# 34549     1         1      1390408       0  2020-01-01      56
# 44824     0         1  16804829671       1  2020-01-01      58
# 22847     1         1      1386361       1  2020-01-01      59
# 46889     0         1  16960157668       0  2020-01-01      57
# ...     ...       ...          ...     ...         ...     ...
# 5342      1         1      1305652       0  2020-01-01      57
# 43043     0         1  21641302468       1  2020-01-01      59
# 43131     0         1  16808074468       0  2020-01-01      59
# 15630     1         1     47004478       1  2020-01-01      58
# 17138     1         1      1505968       0  2020-01-01      59
#
# [42822 rows x 18 columns]

# %% [markdown]
# ##### 'Multa'

# %%
Q1_multa = df['Multa'].quantile(0.25)
Q3_multa = df['Multa'].quantile(0.75)
IQR_multa = Q3_multa - Q1_multa

Lower_Whisker_multa = Q1_multa - (1.5 * IQR_multa)
Upper_Whisker_multa = Q3_multa + (1.5 * IQR_multa)
outliers_multa = df[(df['Multa'] > Upper_Whisker_multa) | (df['Multa'] < Lower_Whisker_multa)]['Multa'].count()

print('Primeiro Quartil: ' + str(Q1_multa))
print('Terceiro Quartil: ' + str(Q3_multa))
print('Amplitude: ' + str(IQR_multa))
print('Quantidade de Outliers: ' + str(outliers_multa))
# Out:
# Primeiro Quartil: 103.52250000000001
# Terceiro Quartil: 2059.0
# Amplitude: 1955.4775
# Quantidade de Outliers: 6226

# %% [markdown]
# #### 3.2 Variáveis Categóricas

# %% [markdown]
# ### Padronização dos valores booleanos 'S' e 'N' (para que possam ser utilizados no modelo como 0s e 1s)

# %%
dict = {
    'S' : 1,
    'N' : 0
}

df_bool = df.replace({'Conta Poupanca' : dict,
            'Conta Salario' : dict, 
            'Cheque Sem Fundo' : dict,
            'Conta Conjunta' : dict})

# %% [markdown]
# >Obs: A variável 'Dependentes' não foi alterada na etapa acima pois os valores numéricos 1 e 0 para representar "Sim" e "Não", respectivamente, poderia ser confundido com o **número de dependentes** que o cliente possui.

# %%
df_bool.head()
# Out:
#   Dependentes  Estado Civil  Idade  Conta Poupanca  Conta Salario  \
# 0           S             2     36               1              0
# 3           N             8     23               0              0
# 4           S             2     33               1              0
# 5           N             2     40               1              0
# 6           N             4     29               1              0
#
#    Quant Adiantamento Deposito  Cheque Sem Fundo  Conta Conjunta  \
# 0                          0.0                 0               0
# 3                          0.0                 0               0
# 4                          0.0                 0               0
# 5                          2.0                 0               0
# 6                          0.0                 0               0
#
#    Valor Emprestimo     Multa    Juros  Valor Emprestimo Atualizado  PAGO  \
# 0           8174.32    263.25  5844.98                     14282.55     1
# 3           1593.00  21472.36  2967.48                     26032.84     1
# 4           2078.97     19.44    46.35                      2144.76     1
# 5           1593.00   1037.44   839.48                      3469.92     1
# 6           1888.24     11.81   279.22                      2179.27     1
#
#    Controle       ID  Genero        Data  Estado
# 0         1  1328587       1  2020-01-01      57
# 3         1  1426138       1  2020-01-01      56
# 4         1  1474504       0  2020-01-01      59
# 5         1  1341838       0  2020-01-01      58
# 6         1  1338805       0  2020-01-01      59

# %% [markdown]
# ### 4. Relações entre variáveis
#
# #### 4.1 Histórico de Pagamento

# %%
df[['PAGO', 'Valor Emprestimo', 'Multa', 'Juros', 'Valor Emprestimo Atualizado']].sort_values(by='Juros', ascending=False).head()
# Out:
#        PAGO  Valor Emprestimo       Multa        Juros  \
# 44063     0            1593.0  31990110.0  23218421.84
# 40819     0            1593.0  29809332.0  19444627.26
# 43182     0            1593.0  17668900.0  13101489.35
# 44552     0            1593.0   4747179.5   3376668.78
# 46851     0            1593.0   5110119.0   3361436.28
#
#        Valor Emprestimo Atualizado
# 44063                  55109962.84
# 40819                  49155390.26
# 43182                  30671820.35
# 44552                   8025279.28
# 46851                   8372986.28

# %%
df[['PAGO', 'Valor Emprestimo', 'Multa', 'Juros', 'Valor Emprestimo Atualizado']].sort_values(by='Valor Emprestimo', ascending=False).head()
# Out:
#        PAGO  Valor Emprestimo     Multa     Juros  Valor Emprestimo Atualizado
# 28063     1          15537.42    557.78   2004.20                     18099.40
# 34549     1          15534.53    557.66   7438.08                     23530.27
# 44824     0          15527.55  28579.73  35568.06                     79675.34
# 22847     1          15525.94    557.32   7691.43                     23774.69
# 46889     0          15522.60  13929.60  17701.70                     47153.90

# %%
sns.regplot(x='Juros', y='Multa', data=df)

# %% [markdown]
# > Acima vemos que as variáveis 'Juros' e 'Multa' parecem possuir uma relação direta, *i.e.*, ambas crescem linearmente (juntas)

# %% [markdown]
# #### 4.2 Renda

# %% [markdown]
# #### 4.3 Idade

# %%
sns.scatterplot(x='Idade', y='Renda Mensal Informal', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-8878139f644d> in <module>
# ----> 1 sns.scatterplot(x='Idade', y='Renda Mensal Informal', data=df)
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1395         x_bins=x_bins, y_bins=y_bins,
#    1396         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1397         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1398     )
#    1399
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     884
#     885         plot_data = self.establish_variables(
# --> 886             x, y, hue, size, style, units, data
#     887         )
#     888
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     135                 if isinstance(var, str):
#     136                     err = "Could not interpret input '{}'".format(var)
# --> 137                     raise ValueError(err)
#     138
#     139             # Extract variable names
#
# ValueError: Could not interpret input 'Renda Mensal Informal'
